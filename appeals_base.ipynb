# %%
from allennlp.predictors.predictor import Predictor as AllenNLPPredictor

class PythonPredictor:
    def __init__(self, config=None):
        self.predictor = AllenNLPPredictor.from_path(
            "bidaf-elmo-model-2018.11.30-charpad.tar"
        )

    def predict(self, payload):
        """
        :param payload: dict containing the keys "passage" and "question" - both keys point to string values. 
        "passage" refers to the source doc that the model will look at while "question" refers to the question 
        asked to the model.
        :returns: a string representing the most probable answer, according to the model.
        """
        prediction = self.predictor.predict(
            passage=payload["passage"], question=payload["question"]
        )
        return prediction["best_span_str"]
    
    def full_predict(self, payload):
        """
        :param payload: dict containing the keys "passage" and "question" - both keys point to string values. 
        "passage" refers to the source doc that the model will look at while "question" refers to the question 
        asked to the model.
        :returns: a dict representing the predictions made by model.
        """
        prediction = self.predictor.predict(
            passage=payload["passage"], question=payload["question"]
        )
        return prediction

# %%
predictor = PythonPredictor()
type(predictor.predictor)
# Out:
# _jsonnet not loaded, treating C:\Users\melvin\AppData\Local\Temp\tmpdvmveebe\config.json as json
# _jsonnet not loaded, treating snippet as json
# D:\melvin\proj-minecraft\env\lib\site-packages\torch\nn\modules\rnn.py:50: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# D:\melvin\proj-minecraft\env\lib\site-packages\allennlp\data\token_indexers\token_characters_indexer.py:56: UserWarning: You are using the default value (0) of `min_padding_length`, which can cause some subtle bugs (more info see https://github.com/allenai/allennlp/issues/1954). Strongly recommend to set a value, usually the maximum size of the convolutional layer size when using CnnEncoder.
#   UserWarning)
# allennlp.predictors.bidaf.BidafPredictor

# %%
# example prediction
payload = {
    "passage": "The trial judges accepted that both the appellants had come into Singapore only with a view to boarding a flight to Amsterdam the next day. They, however, rejected the submission made on behalf of the appellants that bringing drugs into Singapore with a view solely of exporting them would not be an offence under s 7 of the Act. They also rejected Ko’s defence that he did not know that what he was carrying was diamorphine. Accordingly, they convicted the appellants. Against the convictions, this appeal was brought. At the conclusion we dismissed it, and we now give our reasons.Ground (a) can be disposed of very briefly. By s 18(2) of the Act a rebuttable presumption arose that Ko knew the nature of the drug that he was carrying. Once the presumption arose, the onus of discharging it was on Ko. Having heard Ko’s defence, the trial judges were satisfied that he had not discharged the presumption. We have reviewed the record and it is clear that the trial judges were entitled on the evidence before them to arrive at this finding. We saw no reason to interfere.and submitted that s 7 was applicable only when it was sought to punish a master or captain who had contravened s 20. We could not accept that submission. In common with a number of other similar provisions in the Act, what s 20 does is to raise a presumption as to knowledge. By s 20, if it is proved that a drug was found in a ship or aircraft, then the presumption would arise that the drug was imported in the ship or aircraft with the knowledge of the master or captain. No doubt, in such a case, a master or captain may be charged for violating s 7 of the Act but that does not mean to say that s 7 is confined in its operations only to the master of a ship or captain of an aircraft used for the import of drugs. We see no reason why s 7 should not operate against (say) a passenger in a ship or aircraft who was importing drugs. Against such a passenger the presumption under s 20 as to knowledge would obviously not be applicable but (as in this case) the presumption under s 18(2) would apply.",
    "question": "was the appeal dismissed?"
}
prediction = predictor.full_predict(payload)
prediction.keys()
prediction['best_span_str']
# Out:
# 'rejected Ko’s defence that he did not know that what he was carrying was diamorphine. Accordingly, they convicted the appellants. Against the convictions, this appeal was brought. At the conclusion we dismissed it'

# %% [markdown]
# ## From extracted text (in json) to answers
# 1. present whole document and query to system.
# 2. search for potentially relevant paragraphs; this narrows the search space for the subsequent QnA NLP model.
# 2. from these paragraphs, search for answer.
# 3. print top answer (or top few answers)

# %%
import re

class primitiveSearchEngine:
    def __init__(self):
        pass
        
    def and_search(self, itr, queries):
        """
        Searches for the passages/paragraphs that contain a 
        co-occurence of the exact query terms, in any order.
        
        :params itr: a dict containing strings to search through.
        :params queries: a list of query terms.
        :returns: a dict of the form, {key: search_result}.
        """
        regex = "^"
        for term in queries:
            # regex = regex + term + '|'
            regex = regex + rf"(?=.*\b{term}\b)"
        regex = regex + ".*$"
        
        # note: this regex pattern searches for the co-occurence of the
        # exact specified terms, in any order.
        
        pattern = re.compile(regex)
        
        results = {}
        
        for k, v  in itr.items():
            match = pattern.search(v)
            
            if match:
                results[k] = v
        return results
    
    def or_search(self, itr, queries):
        """
        Searches for the paragraphs/strings that contain any of the query terms.
        
        :params itr: a dict containing strings to search through. they key can be a para number.
        :params queries: a list of query terms.
        :returns: a dict of the form, {key: search_result}.
        """
        results = {}
        
        for k, v  in itr.items():
            for term in queries:
                if term in v:
                    results[k] = v
            
        return results
    
    def rule1(self, itr, queries, scorethreshold):
        """
        Rule 1 is an OR search and gives an equal weightage to each keyword
        
        :param scorethreshold: integer. min number of relevant terms that must appear in 
        a text (could be a paragaph). 
        :returns: a dictionary. keys are a subset of itr.keys() and ea value is rule1's 
        relevance score.
        """
        output = dict()
        for para in itr:
            score = 0
            for word in queries:
                if word in itr[para]:
                    score += 1 
            if score >= scorethreshold: 
                output[para] = score

        output = {k: v for k, v in sorted(output.items(), key=lambda x: x[1], reverse=True)}
        return output

# %%
# Porter stemming
import nltk
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize

def tokenise(string): # works on any arbitrary string
    tokens = []
    for sentence in sent_tokenize(string):
        for token in word_tokenize(sentence):
            tokens.append(token)
    return tokens

def stem(token): # tokenizes any particular token
    return PorterStemmer().stem(token)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\melvin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ## Run predictions on documents with 1 simple type of question.

# %%
'''
1. pull out the paragraphs of a valid document
2. run search engine to find relevant paragraphs
3. concatenate relevant paragraphs into a new "source" document
4. feed source and question into QnA model, get answer.
5. manually evaluate if the answer is able to answer the question.
6. auto evaluate if the predicted answer is the same or overlaps with the ground-truth answer.

7. repeat 1-6 for every doc and every question we want to test.

a. we start with questions about whether the accused was convicted. find one good phrasing.
b. can consider testing other phrasings for the same question as well.
c. then we identify other high-prio questions to test.
d. tabulate model's accuracy in answering each type of question.
'''
# Out:
# '\n1. pull out the paragraphs of a valid document\n2. run search engine to find relevant paragraphs\n3. concatenate relevant paragraphs into a new "source" document\n4. feed source and question into QnA model, get answer.\n5. manually evaluate if the answer is able to answer the question.\n6. auto evaluate if the predicted answer is the same or overlaps with the ground-truth answer.\n\n7. repeat 1-6 for every doc and every question we want to test.\n\na. we start with questions about whether the accused was convicted. find one good phrasing.\nb. can consider testing other phrasings for the same question as well.\nc. then we identify other high-prio questions to test.\nd. tabulate model\'s accuracy in answering each type of question.\n'

# %%
import pandas as pd
import numpy as np
import json
# with open('data/cases.json') as f:
#     cases = json.load(f)

# %%
'''
Set up the output_df dataframe from the .json output file.
(based on glowsplint's test_output.py code)
'''
output_df = pd.read_json('data/cases.json')

court_map = {
    'High Court': 'SGHC',
    'Court of Appeal': 'SGCA',
    'District Court': 'SGDC',
    'Court of Criminal Appeal': 'SGCA'
}

output_df['Court'] = output_df.Court.map(court_map)
ref_columns = {
    0: 'refSLR',
    1: 'ref'
}

# Split reference into SLR reference and normal reference
output_df[list(ref_columns.values())] = pd.DataFrame(
    output_df.reference.apply(pd.Series)).rename(columns=ref_columns)
ref_na = output_df['ref'].isna()
output_df.loc[ref_na, 'ref'], output_df.loc[ref_na,'refSLR'] = output_df.refSLR[ref_na], np.nan
output_df.drop('reference', axis=1, inplace=True)

# retain the ordered list of parties in one column, before exploding output_df['parties'] next.
output_df = output_df.assign(listed_parties=output_df.parties)

# Construct the unique reference
exploded_output = output_df.explode('parties')
output_df = exploded_output.loc[exploded_output.parties.str.lower(
) != "public prosecutor"].copy()
output_df['unique_ref'] = output_df['ref'] + \
    ' ' + output_df['parties']
output_df.unique_ref = output_df.unique_ref.str.upper().str.replace(
    "AND ANOTHER", "").str.replace("AND OTHERS", "").str.replace(' +', ' ').str.strip()
output_df = output_df[['unique_ref', 'Date', 'Court',
                                 'coram', 'counsel', 'listed_parties', 'parties', 'paragraphs']]
output_df.rename(columns={'parties': 'accused'}, inplace=True)

# %%
output_df.head()
# Out:
#                                        unique_ref       Date Court  \
# 0                   [2000] SGCA 8 CHIN SIONG KIAN 2000-02-12  SGCA
# 1    [2019] SGCA 81 MOHD AKEBAL S/O GHULAM JILANI 2019-11-28  SGCA
# 1  [2019] SGCA 81 MOHAMMED RUSLI BIN ABDUL RAHMAN 2019-11-28  SGCA
# 2                       [1989] SGHC 75 GOH AH LIM 1989-08-24  SGHC
# 3                   [1989] SGHC 9 KADIR BIN AWANG 1989-02-03  SGHC
#
#                                                coram  \
# 0                   [L P Thean JA, Chao Hick Tin JA]
# 1  [Sundaresh Menon CJ, Tay Yong Kwang JA, Steven...
# 1  [Sundaresh Menon CJ, Tay Yong Kwang JA, Steven...
# 2                       [Lai Kew Chai J, F A Chua J]
# 3            [T S Sinnathuray J, Joseph Grimberg JC]
#
#                                              counsel  \
# 0  {'prosecution': ['Low Cheong Yeow'], 'defence'...
# 1  {'prosecution': ['Chin Jincheng', 'in Criminal...
# 1  {'prosecution': ['Chin Jincheng', 'in Criminal...
# 2  {'prosecution': ['Lee Sing Lit'], 'defence': [...
# 3  {'prosecution': ['Lee Sing Lit'], 'defence': [...
#
#                                       listed_parties  \
# 0               [Chin Siong Kian, Public Prosecutor]
# 1  [Mohd Akebal s/o Ghulam Jilani, Public Prosecu...
# 1  [Mohd Akebal s/o Ghulam Jilani, Public Prosecu...
# 2                    [Public Prosecutor, Goh Ah Lim]
# 3               [Public Prosecutor, Kadir bin Awang]
#
#                            accused  \
# 0                  Chin Siong Kian
# 1    Mohd Akebal s/o Ghulam Jilani
# 1  Mohammed Rusli Bin Abdul Rahman
# 2                       Goh Ah Lim
# 3                  Kadir bin Awang
#
#                                           paragraphs
# 0  {'1': 'On 6 September 1999 the appellant, toge...
# 1  {'1': 'These appeals arise from the joint tria...
# 1  {'1': 'These appeals arise from the joint tria...
# 2  {'1': 'The accused, a male Chinese aged 46, fa...
# 3  {'1': 'Kadir bin Awang (“the accused”) was cha...

# %%
# filter out cases that are definitely appeal cases
appeals_indices = []
for i in range(len(output_df)):
    if 'SGCA' in output_df.iloc[i]["Court"]:
        appeals_indices.append(i)

appeals_df = output_df.iloc[appeals_indices]
appeals_df.head()
# Out:
#                                        unique_ref       Date Court  \
# 0                   [2000] SGCA 8 CHIN SIONG KIAN 2000-02-12  SGCA
# 1    [2019] SGCA 81 MOHD AKEBAL S/O GHULAM JILANI 2019-11-28  SGCA
# 1  [2019] SGCA 81 MOHAMMED RUSLI BIN ABDUL RAHMAN 2019-11-28  SGCA
# 5                     [1991] SGCA 14 SIM AH CHEOH 1991-05-31  SGCA
# 7                    [1992] SGCA 30 KO MUN CHEUNG 1992-04-30  SGCA
#
#                                                coram  \
# 0                   [L P Thean JA, Chao Hick Tin JA]
# 1  [Sundaresh Menon CJ, Tay Yong Kwang JA, Steven...
# 1  [Sundaresh Menon CJ, Tay Yong Kwang JA, Steven...
# 5  [Yong Pung How CJ, Chan Sek Keong J, L P Thean J]
# 7      [L P Thean J, Goh Joon Seng J, S Rajendran J]
#
#                                              counsel  \
# 0  {'prosecution': ['Low Cheong Yeow'], 'defence'...
# 1  {'prosecution': ['Chin Jincheng', 'in Criminal...
# 1  {'prosecution': ['Chin Jincheng', 'in Criminal...
# 5  {'prosecution': ['Chan Seng Onn'], 'defence': ...
# 7  {'prosecution': [], 'defence': ['P Suppiah', '...
#
#                                       listed_parties  \
# 0               [Chin Siong Kian, Public Prosecutor]
# 1  [Mohd Akebal s/o Ghulam Jilani, Public Prosecu...
# 1  [Mohd Akebal s/o Ghulam Jilani, Public Prosecu...
# 5       [Sim Ah Cheoh and others, Public Prosecutor]
# 7     [Ko Mun Cheung and another, Public Prosecutor]
#
#                            accused  \
# 0                  Chin Siong Kian
# 1    Mohd Akebal s/o Ghulam Jilani
# 1  Mohammed Rusli Bin Abdul Rahman
# 5          Sim Ah Cheoh and others
# 7        Ko Mun Cheung and another
#
#                                           paragraphs
# 0  {'1': 'On 6 September 1999 the appellant, toge...
# 1  {'1': 'These appeals arise from the joint tria...
# 1  {'1': 'These appeals arise from the joint tria...
# 5  {'1': 'The first appellant, Sim Ah Cheoh (“Sim...
# 7  {'1': 'The two appellants, Ko Mun Cheung (“Ko”...

# %%
searchEngine = primitiveSearchEngine()

ConvictionTrialQ = ["accordingly", "acquit", "charge", "convict", "element", "guilty", "made out", "prove", "reasonable doubt", "reasons", "satisfied", "sentence", "therefore" ]
ConvictionAppealQ = ConvictionTrialQ + ["affirm", "allow", "dismiss"]

#add porter stemming to capture more relevant words.
search_terms = ConvictionAppealQ
search_terms = [stem(term) for term in search_terms] # remove if stemming doesn't help

# %%
from random import choice
from nltk.tokenize.treebank import TreebankWordDetokenizer
def predict_multiple(cases_df, search_terms, print_output=True):
    """
    todo: put under the predictor class.
    """
    preds = []
    for i in range(len(cases_df)):
        print(f"{i+1}/{len(cases_df)}")
        # determine appellant.
        if cases_df.iloc[i]['listed_parties'][0].lower() != "public prosecutor":
            appellant = cases_df.iloc[i]['accused']
            and_index = appellant.find("and")
            if and_index != -1:
                # if 'X and others' then cut away ' and others'
                appellant = appellant[0:and_index - 1]
        else:
            appellant = "public prosecutor"
        
        qn = f"was {appellant}'s appeal dismissed?"
        #qn = f"was {appellant}'s appeal allowed?"
        # todo: modify this code chunk to ask multiple question-phrasings at once
        # instead of only one question-phrasing per document.
        
        sentences = {}
        item_num = 1
        for para_num, para in cases_df.iloc[i]['paragraphs'].items():
            for sent in sent_tokenize(para):
                sentences[item_num] = sent
                item_num = item_num + 1
        
        # Find sentences related to search terms.
        # rule1() yields item numbers that contain ANY of the search terms. 
        SCORE_THRESHOLD = 1  # arbitrary threshold for "rule1"; result must be greater than thres.
        results = searchEngine.rule1(sentences, search_terms, SCORE_THRESHOLD)
        
        predicted_sent = 'NA' # prediction defaults to NA if no relevant paras found.
        if len(results) > 0:    
            top_item_keys = list()
            keys_list = list(results.keys())
            max_score = results[keys_list[0]]  # because keys_list is presorted according to
            # descending score
            for item_num, score in results.items():
                if score == max_score:
                    top_item_keys.append(item_num)
                else:
                    break

            random_key = choice(top_item_keys)
            predicted_sent = sentences[random_key] 
    
        preds.append(predicted_sent)
        
        if print_output:
            # TODO: use logger.
            print(f"number of sentences found: {len(sentences)}")       
            print(f"number of candidate sentences found: {len(top_item_keys)}")       
            print(f"qn: {qn}")
            print(f"predicted sent: {predicted_sent}")
            print()
    return preds

# %%
preds = predict_multiple(appeals_df, search_terms)
len(preds)
# Out:
# 1/131
# number of sentences found: 224
# number of candidate sentences found: 2
# qn: was Chin Siong Kian's appeal dismissed?
# predicted sent: The trial judge therefore convicted the appellant and Wan under the amended joint charge and sentenced them to suffer death.
#
# 2/131
# number of sentences found: 107
# number of candidate sentences found: 4
# qn: was Mohd Akebal s/o Ghulam Jilani's appeal dismissed?
# predicted sent: (a)     Akebal was convicted on a single charge of trafficking not less than 29.06g of diamorphine, an offence under s 5(1)(a) of the Misuse of Drugs Act (Cap 185, 2008 Rev Ed) (“MDA”), and sentenced to death.
#
# 3/131
# number of sentences found: 107
# number of candidate sentences found: 4
# qn: was Mohammed Rusli Bin Abdul Rahman's appeal dismissed?
# predicted sent: (c)     Andi was convicted on one charge of possessing not less than 29.06g of diamorphine for the purpose of trafficking under s 5(1)(a) read with s 5(2) of the MDA, and sentenced to life imprisonment and 15 strokes of the cane.
#
# 4/131
# number of sentences found: 180
# number of candidate sentences found: 11
# qn: was Sim Ah Cheoh's appeal dismissed?
# predicted sent: At the close of the case for the Prosecution, counsel for the appellants respectively submitted that no case had been made out against the appellants, which, if unrebutted, would warrant their convictions on the charges against them.
#
# 5/131
# number of sentences found: 93
# number of candidate sentences found: 2
# qn: was Ko Mun Cheung's appeal dismissed?
# predicted sent: At the conclusion we dismissed it, and we now give our reasons.
#
# 6/131
# number of sentences found: 149
# number of candidate sentences found: 2
# qn: was Ng Kwok Chun's appeal dismissed?
# predicted sent: The court reviewed the authorities on the meaning of import and approved, inter alia, Geesman ([9] supra) and MacDonald JA, delivering the main judgment of the court, stated the following essential elements of the charge of importation under s 5 (at 540):
#
# 7/131
# number of sentences found: 128
# number of candidate sentences found: 3
# qn: was Tse Po Chung Nathan's appeal dismissed?
# predicted sent: The master of the vessel was also convicted of knowingly allowing the vessel to be used in the importation of goods contrary to s 233A of the Act.
#
# 8/131
# number of sentences found: 59
# number of candidate sentences found: 1
# qn: was public prosecutor's appeal dismissed?
# predicted sent: We therefore allowed the appeal and made the orders stated above.
#
# 9/131
# number of sentences found: 123
# number of candidate sentences found: 1
# qn: was public prosecutor's appeal dismissed?
# predicted sent: The Public Prosecutor appealed against her acquittal and at the end of the hearing before us, we dismissed the appeal for the reasons which follow.
#
# 10/131
# number of sentences found: 91
# number of candidate sentences found: 1
# qn: was Fung Yuk Shing's appeal dismissed?
# predicted sent: Since neither defence raised by the appellant was sufficient to raise a reasonable doubt in the prosecution case, the appellant was convicted of the charge against him.
#
# 11/131
# number of sentences found: 181
# number of candidate sentences found: 1
# qn: was public prosecutor's appeal dismissed?
# predicted sent: The Public Prosecutor appealed against the respondent’s acquittal and at the end of the appeal, we allowed the appeal, convicted the respondent of the charge and sentenced the respondent to death.
#
# 12/131
# number of sentences found: 251
# number of candidate sentences found: 4
# qn: was Kong Weng Chong's appeal dismissed?
# predicted sent: There, at the trial, the judge allowed a waiter of the restaurant, the proprietor of which had complained against the accused, to act as the interpreter and it was held that such act amounted to an irregularity of such a character as to make it unsafe in the circumstances to let the conviction stand.
#
# 13/131
# number of sentences found: 127
# number of candidate sentences found: 1
# qn: was Van Damme Johannes's appeal dismissed?
# predicted sent: It is accepted that the onus is always on the Prosecution to prove its case beyond a reasonable doubt but, in the context of the Act, the law has provided the Prosecution with presumptions and the court must have regard to them.
#
# 14/131
# number of sentences found: 118
# number of candidate sentences found: 2
# qn: was Hyecinth Ihejirika's appeal dismissed?
# predicted sent: It is for the Prosecution to discharge the legal burden of proving its case beyond reasonable doubt.
#
# 15/131
# number of sentences found: 163
# number of candidate sentences found: 4
# qn: was Ubaka Chris Chinenye's appeal dismissed?
# predicted sent: Just as the learned judge found no merit in them, we too did not find any merit in the appellant’s contentions and accordingly we dismissed the appeal and confirmed the sentence of death passed by the learned trial judge on the appellant.
#
# 16/131
# number of sentences found: 211
# number of candidate sentences found: 1
# qn: was Navarat Maykha's appeal dismissed?
# predicted sent: He was satisfied that the Prosecution had proved its case beyond reasonable doubt and accordingly convicted her.
#
# 17/131
# number of sentences found: 98
# number of candidate sentences found: 3
# qn: was Mat Repin bin Mamat's appeal dismissed?
# predicted sent: As the tests had shown that all nine samples belonged to the plant of the genus cannabis from which the resin had not been extracted, we had no doubt that the Prosecution had proved, beyond reasonable doubt, that the plant material seized from the appellant was not less than 1,026g of cannabis as defined by s 2 of the Act.
#
# 18/131
# number of sentences found: 51
# number of candidate sentences found: 2
# qn: was Tsang Kai Mong Elke's appeal dismissed?
# predicted sent: The appellant, a female Hong Kong resident, was convicted on 19 October 1993 and sentenced to death on a charge of having imported into Singapore on 26 July 1992 a controlled drug without any authorisation and having thereby committed an offence under s 7 punishable under s 33 of the Misuse of Drugs Act (Cap 185) (“the Act”).
#
# 19/131
# number of sentences found: 179
# number of candidate sentences found: 6
# qn: was Chan Chi Pun's appeal dismissed?
# predicted sent: In addition, he held that the Prosecution had sufficiently established the mental element for the offence charged.
#
# 20/131
# number of sentences found: 203
# number of candidate sentences found: 4
# qn: was Low Kok Wai's appeal dismissed?
# predicted sent: The appellant was, on 4 March 1993, tried and convicted on the following charge:
#
# 21/131
# number of sentences found: 165
# number of candidate sentences found: 1
# qn: was Anyanwu's appeal dismissed?
# predicted sent: In the oral judgment the trial judge stated the charge, the prosecution case, the defence and his findings that the Prosecution had proved the case beyond reasonable doubt, that he had no doubt that the appellant knew that diamorphine was concealed in the rice cookers, and that, accordingly, the appellant was guilty of the charge.
#
# 22/131
# number of sentences found: 266
# number of candidate sentences found: 5
# qn: was Jasbir Singh's appeal dismissed?
# predicted sent: Any statement subjected to a voir dire is admitted in evidence only after the trial judge finds, on the basis of all the evidence adduced, that the Prosecution has proved beyond reasonable doubt the voluntariness of the statement.
#
# 23/131
# number of sentences found: 261
# number of candidate sentences found: 3
# qn: was public prosecutor's appeal dismissed?
# predicted sent: We have pointed out that the learned judicial commissioner took a poor view of the credibility of these three witnesses and, for that reason, not all of the above allegations can be said to have been proved beyond reasonable doubt.
#
# 24/131
# number of sentences found: 331
# number of candidate sentences found: 2
# qn: was Hartej Sidhu's appeal dismissed?
# predicted sent: For the reasons given above, we were of the view that there were no merits whatsoever in the appeals and we therefore dismissed them.
#
# 25/131
# number of sentences found: 190
# number of candidate sentences found: 5
# qn: was Lam Cheuk Wang's appeal dismissed?
# predicted sent: Second, he asserted that the trial judge had erred in failing to address the burden of proof upon the Prosecution of the second appellant’s guilt, ie proof beyond reasonable doubt.
#
# 26/131
# number of sentences found: 284
# number of candidate sentences found: 4
# qn: was Don Promphinit's appeal dismissed?
# predicted sent: Accordingly, the trial judge concluded that the Prosecution had discharged its burden and proved the case against all the three appellants beyond reasonable doubt.
#
# 27/131
# number of sentences found: 90
# number of candidate sentences found: 5
# qn: was Mou Pui Peng's appeal dismissed?
# predicted sent: The appellant was convicted by the High Court of the offence of importing into Singapore not less than 4,096g of diamorphine under s 7 of the Misuse of Drugs Act (Cap 185) (“the Act”), and was sentenced to suffer death.
#
# 28/131
# number of sentences found: 197
# number of candidate sentences found: 5
# qn: was Osman bin Din's appeal dismissed?
# predicted sent: For the following reasons below, we were not convinced that the appellant had discharged his burden on the balance of probabilities.
#
# 29/131
# number of sentences found: 157
# number of candidate sentences found: 2
# qn: was Tan Yew Lee's appeal dismissed?
# predicted sent: Accordingly, we are of the view that the appellant was rightly convicted beyond reasonable doubt.
#
# 30/131
# number of sentences found: 187
# number of candidate sentences found: 4
# qn: was public prosecutor's appeal dismissed?
# predicted sent: This statement, if accepted, together with the other evidence adduced by the Prosecution establishes the essential elements of the charge against the respondent.
#
# 31/131
# number of sentences found: 489
# number of candidate sentences found: 2
# qn: was Lee Yuan Kwang's appeal dismissed?
# predicted sent: We accordingly dismiss his appeals against conviction on both charges.
#
# 32/131
# number of sentences found: 374
# number of candidate sentences found: 3
# qn: was public prosecutor's appeal dismissed?
# predicted sent: The respondent was acquitted of the charge of importing into Singapore not less than 3,468g of diamorphine, an offence under s 7 of the Misuse of Drugs Act (Cap 185) (“the Act”).
#
# 33/131
# number of sentences found: 200
# number of candidate sentences found: 1
# qn: was Goh Joon Tong's appeal dismissed?
# predicted sent: He found that the Prosecution had proved its case against all the three accused beyond any reasonable doubt and he convicted each of them on the charge they each faced.
#
# 34/131
# number of sentences found: 434
# number of candidate sentences found: 2
# qn: was Foong Seow Ngui's appeal dismissed?
# predicted sent: Relying on Chin Seow Noi v PP [1993] 3 SLR(R) 566, he was of the view that Tan could be convicted if he was satisfied from the evidence in the confessions beyond a reasonable doubt of Tan’s guilt.
#
# 35/131
# number of sentences found: 111
# number of candidate sentences found: 2
# qn: was Lee Meng Hong's appeal dismissed?
# predicted sent: The presence of the only key to Room 113 on the appellant, his oral statement to S/Sgt Thng, his s 122(6) and s 121 statements had proved beyond reasonable doubt that the appellant was in possession of the heroin.
#
# 36/131
# number of sentences found: 201
# number of candidate sentences found: 1
# qn: was Lim Lye Huat Benny's appeal dismissed?
# predicted sent: Being satisfied that the Prosecution had proved its case, the learned judge convicted the appellant as charged.
#
# 37/131
# number of sentences found: 124
# number of candidate sentences found: 2
# qn: was Wong Yoke Wah's appeal dismissed?
# predicted sent: We heard his appeal against the conviction on 24 October 1995 which we dismissed for the reasons that follow.
#
# 38/131
# number of sentences found: 109
# number of candidate sentences found: 1
# qn: was Mazlan bin Sulaiman's appeal dismissed?
# predicted sent: As a result, the appellant's -condition improved and he was discharged on 8 May 1995.
#
# 39/131
# number of sentences found: 120
# number of candidate sentences found: 2
# qn: was Muhamed Hazani bin Ghani alias Abu Hanifah's appeal dismissed?
# predicted sent: In our judgment, the learned trial judge was right in finding that the charge against the appellant had been proved beyond reasonable doubt.
#
# 40/131
# number of sentences found: 258
# number of candidate sentences found: 1
# qn: was Tan Meng Jee's appeal dismissed?
# predicted sent: Nonetheless, it should never be forgotten that the law only convicts an accused when each element of the offence is proven beyond reasonable doubt.
#
# 41/131
# number of sentences found: 229
# number of candidate sentences found: 1
# qn: was Abdul Raman bin Yusof's appeal dismissed?
# predicted sent: For the foregoing reasons, both appellants were rightly convicted of trafficking in 590.23g of cannabis and sentenced with the statutory penalty.
#
# 42/131
# number of sentences found: 385
# number of candidate sentences found: 1
# qn: was Muhammad Jefrry's appeal dismissed?
# predicted sent: The Prosecution had thus proved beyond a reasonable doubt that the aforesaid heroin was in the possession of the appellant.
#
# 43/131
# number of sentences found: 156
# number of candidate sentences found: 1
# qn: was Teh Thiam Huat's appeal dismissed?
# predicted sent: We should, however, mention that an issue was raised that as the capital charge of trafficking was a “common intention charge” and the learned judge having acquitted the other conspirator, Tay Bee Hoon, the conviction of the appellant without amending the charge was irregular.
#
# 44/131
# number of sentences found: 127
# number of candidate sentences found: 1
# qn: was Chua Kiat Ann's appeal dismissed?
# predicted sent: In our judgment, the appellant was rightly convicted of the amalgamated charge, and we dismissed the appeal.
#
# 45/131
# number of sentences found: 129
# number of candidate sentences found: 2
# qn: was Tan Lay Keat's appeal dismissed?
# predicted sent: The appellant was convicted on a charge under s 5(1)(a) of the Misuse of Drugs Act (Cap 185) of trafficking by transporting six packets of heroin containing not less than 294.5g of diamorphine in taxi SH 2894G from Bishan Street 22 to Ophir Road between 11.45am and 12.00noon on 19 July 1996.
#
# 46/131
# number of sentences found: 208
# number of candidate sentences found: 4
# qn: was Tan Chuan Ten's appeal dismissed?
# predicted sent: On appeal by the Prosecution, this court held that a prima facie case had been made out, and that there was some evidence, not inherently incredible, which, if accepted, would establish all the essential elements of the charge and remitted the case to the High Court with a direction that T’s defence be called: PP v Tan Aik Heng [1995] 1 SLR(R) 710.
#
# 47/131
# number of sentences found: 129
# number of candidate sentences found: 3
# qn: was Low Cheng Soon's appeal dismissed?
# predicted sent: We dismissed the appeal and now give our reasons.
#
# 48/131
# number of sentences found: 66
# number of candidate sentences found: 1
# qn: was Lau Boon Huat's appeal dismissed?
# predicted sent: On 7 July 1997 we dismissed the appellant’s appeal against his conviction on a charge of trafficking in not less than 454.90g of diamorphine contained in ten packets of substance by transporting the same for the purpose of delivery to an unknown person at about 12.55pm on 3 August 1996 at Block 753 Yishun Street 72, Singapore, an offence under s 5(1)(a) and punishable with death under s 33 of the Misuse of Drugs Act (Cap 185).
#
# 49/131
# number of sentences found: 217
# number of candidate sentences found: 1
# qn: was Fun Seong Cheng's appeal dismissed?
# predicted sent: At the end of the voir dire, as noted above, the learned judge admitted the above questions and answers as he was satisfied that the Prosecution had proven beyond reasonable doubt that the answers were given voluntarily.
#
# 50/131
# number of sentences found: 230
# number of candidate sentences found: 1
# qn: was Yong Yow Chee's appeal dismissed?
# predicted sent: A preliminary point was the appellant’s submission that the trial judge erred in law when he allowed the appellant to be tried on a capital charge coupled with a non-capital charge when it is the accepted rule of practice “that a capital charge should not generally speaking be coupled with a non-capital charge in the same indictment and that the reason for this rule is that when an accused person is defending himself on a capital charge he ought not in fairness to be required to defend himself on other additional charges at the same trial”.
#
# 51/131
# number of sentences found: 229
# number of candidate sentences found: 1
# qn: was Yeo Choon Huat's appeal dismissed?
# predicted sent: At the end of the trial, the appellant was convicted on the amended charge and sentenced to the mandatory punishment of death.
#
# 52/131
# number of sentences found: 292
# number of candidate sentences found: 6
# qn: was Mohd Ariff bin Mat Rifin's appeal dismissed?
# predicted sent: Mindful of the Prosecution’s onerous burden of proof (no presumptions were triggered against Azman), we unanimously concluded that this burden had not been discharged beyond a reasonable doubt.
#
# 53/131
# number of sentences found: 126
# number of candidate sentences found: 1
# qn: was Loh Kim Cheng's appeal dismissed?
# predicted sent: But the Prosecution’s case, to warrant a conviction, must be proved beyond a reasonable doubt.
#
# 54/131
# number of sentences found: 218
# number of candidate sentences found: 3
# qn: was Heng Aik Ren Thomas's appeal dismissed?
# predicted sent: For the reasons given above, we were of the view that the identity of the appellant as the person who placed the heroin in the dry riser compartment was proved beyond a reasonable doubt.
#
# 55/131
# number of sentences found: 96
# number of candidate sentences found: 1
# qn: was Chou Kooi Pang's appeal dismissed?
# predicted sent: The court rejected the defences of both of them and they were convicted on their respective charges and sentenced to suffer death.
#
# 56/131
# number of sentences found: 474
# number of candidate sentences found: 2
# qn: was Chai Chien Wei Kelvin's appeal dismissed?
# predicted sent: Fourth, the learned judicial commissioner had erred in law and in fact in drawing an adverse inference against the appellant for electing to remain silent without first satisfying himself that the Prosecution had made out a case that was coherent and convincing, such that the charge if unrebutted would have been proved beyond a reasonable doubt.
#
# 57/131
# number of sentences found: 282
# number of candidate sentences found: 2
# qn: was Cheng Heng Lee's appeal dismissed?
# predicted sent: Thus, we dismissed Cheng’s appeal as the elements which constitute the offence of drug trafficking under s 5(1)(a) of the Misuse of Drugs Act, namely, the accused (a) has possession of the controlled drug in question, (b) has done the act of trafficking in one of the forms set out in s 2 of the Act, and (c) has knowledge of the nature of the drug which he was in possession of (Tan Meng Jee v PP [1996] 2 SLR(R) 178), had been made out.
#
# 58/131
# number of sentences found: 497
# number of candidate sentences found: 1
# qn: was Gulam bin Notan Mohd Shariff Jamalddin's appeal dismissed?
# predicted sent: We therefore concluded that all the elements of the offence with which the appellants were charged had been proven beyond a reasonable doubt.
#
# 59/131
# number of sentences found: 141
# number of candidate sentences found: 2
# qn: was Satli bin Masot's appeal dismissed?
# predicted sent: In the circumstances, we were satisfied that the Prosecution had proven beyond a reasonable doubt that the drug exhibits analysed by Dr Lee were the same drugs that were seized from the appellant’s flat.
#
# 60/131
# number of sentences found: 322
# number of candidate sentences found: 1
# qn: was Aziz bin Abdul Kadir's appeal dismissed?
# predicted sent: At the end of the trial, Raseed was acquitted and discharged on the basis that neither the requisite possession nor common intention to traffic were proven against him beyond a reasonable doubt.
#
# 61/131
# number of sentences found: 187
# number of candidate sentences found: 1
# qn: was Su Chee Kiong's appeal dismissed?
# predicted sent: The trial judge was satisfied that the Prosecution had proved beyond reasonable doubt that the appellant was in possession of the drugs found in the flat.
#
# 62/131
# number of sentences found: 144
# number of candidate sentences found: 1
# qn: was Abdul Ra'uf bin Abdul Rahman's appeal dismissed?
# predicted sent: The trial judge held that the Prosecution had proven beyond reasonable doubt the elements of the charge.
#
# 63/131
# number of sentences found: 344
# number of candidate sentences found: 1
# qn: was Sharom bin Ahmad's appeal dismissed?
# predicted sent: We therefore upheld the convictions and mandatory death sentences passed by the trial judge and dismissed both the appeals.
#
# 64/131
# number of sentences found: 101
# number of candidate sentences found: 1
# qn: was Sim Teck Ho's appeal dismissed?
# predicted sent: For these reasons, we dismissed the appeal and affirmed the sentence.
#
# 65/131
# number of sentences found: 182
# number of candidate sentences found: 1
# qn: was Syed Yasser Arafat bin Shaik Mohamed's appeal dismissed?
# predicted sent: For the above reasons, we dismissed the appeal and upheld the conviction and sentence.
#
# 66/131
# number of sentences found: 212
# number of candidate sentences found: 1
# qn: was Lim Beng Soon's appeal dismissed?
# predicted sent: In the light of the above, we found that the Prosecution had proved the charge beyond reasonable doubt and that the appellant was rightly convicted.
#
# 67/131
# number of sentences found: 262
# number of candidate sentences found: 4
# qn: was Suboh bin Ramli's appeal dismissed?
# predicted sent: To make good this charge the Prosecution has to prove beyond reasonable doubt that Suboh had possession of the drugs at the material time: Low Kok Wai v PP [1994] 1 SLR(R) 64, PP v Wan Yue Kong [1995] 1 SLR(R) 83 and Lim Lye Huat Benny v PP [1995] 3 SLR(R) 689.
#
# 68/131
# number of sentences found: 332
# number of candidate sentences found: 1
# qn: was Thiruselvam s/o Nagaratnam's appeal dismissed?
# predicted sent: In our judgment, the evidence against the appellant was overwhelming, and the trial judge’s finding that the charge against the appellant had been proved beyond reasonable doubt was fully supported by the evidence.
#
# 69/131
# number of sentences found: 128
# number of candidate sentences found: 1
# qn: was Ramis a/l Mun's appeal dismissed?
# predicted sent: We therefore dismissed the appeal against conviction and sentence.
#
# 70/131
# number of sentences found: 144
# number of candidate sentences found: 4
# qn: was Zulfikar bin Mustaffah's appeal dismissed?
# predicted sent: Consequently, Choo JC held that the charge against the appellant had been made out.
#
# 71/131
# number of sentences found: 153
# number of candidate sentences found: 4
# qn: was Abdul Malik bin Abdul Jamil's appeal dismissed?
# predicted sent: The charge was therefore established.
#
# 72/131
# number of sentences found: 104
# number of candidate sentences found: 4
# qn: was Syed Abdul Mutalip bin Syed Sidek's appeal dismissed?
# predicted sent: As the appellants were not able to establish that the trial judge erred in convicting them, their appeals were dismissed.
#
# 73/131
# number of sentences found: 116
# number of candidate sentences found: 2
# qn: was Bala Murugan a/l Krishnan's appeal dismissed?
# predicted sent: For the reasons we have given, we agreed with the findings of the judicial commissioner that the Prosecution had proven the guilt of both appellants beyond a reasonable doubt.
#
# 74/131
# number of sentences found: 284
# number of candidate sentences found: 5
# qn: was Raman Selvam s/o Renganathan's appeal dismissed?
# predicted sent: The appellant’s control of the keys was therefore an important fact, which the Prosecution needed to prove.
#
# 75/131
# number of sentences found: 146
# number of candidate sentences found: 1
# qn: was Teo Yeow Chuah's appeal dismissed?
# predicted sent: Having considered all the arguments presented and the grounds appearing in Teo’s petition of appeal, we were satisfied that the Prosecution had indeed discharged its ultimate burden of proving its case against Teo beyond reasonable doubt.
#
# 76/131
# number of sentences found: 361
# number of candidate sentences found: 2
# qn: was Nguyen Tuong Van's appeal dismissed?
# predicted sent: Where there is a break in the chain of custody, and a reasonable doubt arises as to the identity of the drug exhibits, then the Prosecution has not discharged its burden, and has failed to make out a prima facie case against the accused: Abdul Rashid bin Mohamed v PP ([22] supra) at [17].
#
# 77/131
# number of sentences found: 99
# number of candidate sentences found: 1
# qn: was Mohd Halmi bin Hamid's appeal dismissed?
# predicted sent: As in any crime, the Prosecution is obliged to prove its case, and that includes every aspect of the elements that constitute the offence, beyond reasonable doubt.
#
# 78/131
# number of sentences found: 119
# number of candidate sentences found: 1
# qn: was Iwuchukwu Amara Tochi's appeal dismissed?
# predicted sent: The trial judge thus had no difficulty finding that the act of importing the drugs was proved beyond reasonable doubt and accordingly, found the first appellant guilty as charged and convicted him.
#
# 79/131
# number of sentences found: 702
# number of candidate sentences found: 3
# qn: was Tan Kiam Peng's appeal dismissed?
# predicted sent: Put simply, if no possession on the part of the accused is proved in the first instance, it is futile – indeed, illogical – to consider whether there is knowledge of the nature of the thing possessed (see, for example, the Singapore High Court decision of PP v Wong Wai Hung [1992] 2 SLR(R) 918, where the second accused was therefore acquitted).
#
# 80/131
# number of sentences found: 100
# number of candidate sentences found: 2
# qn: was Teo Cheow Kim's appeal dismissed?
# predicted sent: Accordingly, the Judge found that the Prosecution had made out its case against the appellant beyond a reasonable doubt.
#
# 81/131
# number of sentences found: 101
# number of candidate sentences found: 4
# qn: was Tan Chin Hock's appeal dismissed?
# predicted sent: At the conclusion of the hearing of the appeal, we dismissed the appeal as there was, in our view, no reasonable doubt that the appellant was guilty of the offence which he was convicted of.
#
# 82/131
# number of sentences found: 81
# number of candidate sentences found: 6
# qn: was Kwek Seow Hock's appeal dismissed?
# predicted sent: Accordingly, the Prosecution was held to have established its case beyond reasonable doubt (see [78] of the GD).
#
# 83/131
# number of sentences found: 183
# number of candidate sentences found: 1
# qn: was Ramalingam Ravinthran's appeal dismissed?
# predicted sent: For the reasons given above, we dismissed the appellant’s appeal as we were satisfied with the Judge’s finding that the appellant had actual knowledge that the sports bag contained cannabis and cannabis mixture.
#
# 84/131
# number of sentences found: 147
# number of candidate sentences found: 1
# qn: was Tang Hai Liang's appeal dismissed?
# predicted sent: For this question to be answered in the affirmative, the Prosecution must have proved beyond a reasonable doubt the three main elements of the offence set out in the Charge, namely: (a) the Appellant’s possession of the diamorphine recovered from the Flat; (b) the Appellant’s knowledge of the diamorphine; and (c) the Appellant’s possession of the diamorphine for the purpose of trafficking.
#
# 85/131
# number of sentences found: 119
# number of candidate sentences found: 2
# qn: was NAGAENTHRAN A/L K DHARMALINGAM's appeal dismissed?
# predicted sent: Accordingly, he convicted the appellant of the offence charged and sentenced him to death as mandated by s 33 of the MDA read together with the Second Schedule to the MDA.
#
# 86/131
# number of sentences found: 353
# number of candidate sentences found: 1
# qn: was Pang Siew Fum's appeal dismissed?
# predicted sent: The Judge found that the evidence against Pang and Cheong was incontrovertible and that the Prosecution had proven its case beyond a reasonable doubt.
#
# 87/131
# number of sentences found: 278
# number of candidate sentences found: 2
# qn: was Thong Ah Fat's appeal dismissed?
# predicted sent: The Judge, in a brief judgment of five paragraphs, explained why he found the Appellant guilty of the charge and upon convicting him, sentenced him to suffer the mandatory death penalty.
#
# 88/131
# number of sentences found: 144
# number of candidate sentences found: 1
# qn: was Chan Heng Kong's appeal dismissed?
# predicted sent: For the reasons stated above, we dismiss this appeal where Chan’s conviction is concerned.
#
# 89/131
# number of sentences found: 184
# number of candidate sentences found: 2
# qn: was Azman bin Mohamed Sanwan's appeal dismissed?
# predicted sent: This is an appeal brought by Azman bin Mohamed Sanwan (“the Appellant”) against the decision of a High Court judge (“the Trial Judge”) convicting him of a capital charge brought under the Misuse of Drugs Act (Cap 185, 2001 Rev Ed) (“the MDA (2001 Ed)”) while acquitting his two co-accused, namely, Tamil Salvem (“Tamil”) and Balasubramaniam s/o Murugesan (“Bala”), of the same capital charge (see Public Prosecutor v Azman bin Mohamed Sanwan [2010] SGHC 196 (“the Judgment”)) (the offence which the Appellant was charged with was allegedly committed on 28 April 2007, before the current version of the Misuse of Drugs Act (ie, the Misuse of Drugs Act (Cap 185, 2008 Rev Ed)) came into force).
#
# 90/131
# number of sentences found: 204
# number of candidate sentences found: 2
# qn: was Quek Hock Lye's appeal dismissed?
# predicted sent: If the charge was proven beyond a reasonable doubt, the court would be compelled to sentence A to the mandatory death penalty whereas B would only be liable for life imprisonment.
#
# 91/131
# number of sentences found: 344
# number of candidate sentences found: 2
# qn: was public prosecutor's appeal dismissed?
# predicted sent: At the first hearing of this appeal, we asked the Prosecution to address us on the issue from first principles as this court in Khor Soon Lee did not issue written grounds for its decision to convict the appellant in that case of attempted importation (Khor Soon Lee dealt only with this court’s reasons for acquitting the appellant of the capital charge of importing diamorphine).
#
# 92/131
# number of sentences found: 83
# number of candidate sentences found: 1
# qn: was Dinesh Pillai a/l K Raja Retnam's appeal dismissed?
# predicted sent: In substance, his argument was that the evidence showed that the applicant did not know (or at least there was a reasonable doubt that he knew) that he was carrying a controlled drug or that he did not know the nature of the controlled drug, and therefore the Public Prosecutor in bringing the capital charge against the applicant had acted in bad faith.
#
# 93/131
# number of sentences found: 226
# number of candidate sentences found: 5
# qn: was public prosecutor's appeal dismissed?
# predicted sent: Accordingly, we set aside the orders at [66] of the Judgment (where the High Court set aside the Respondent’s conviction and remitted the case to the District Court for a new trial) and dismiss the Respondent’s appeal against his sentence, given that his sentence of 5 years’ imprisonment and 5 strokes of the cane is the mandatory minimum sentence for his offence of importing a Class A drug.
#
# 94/131
# number of sentences found: 311
# number of candidate sentences found: 1
# qn: was Muhammad Ridzuan bin Md Ali's appeal dismissed?
# predicted sent: Therefore, should it be proven beyond a reasonable doubt that the elements of s 34 PC are satisfied, constructive liability for the offence of trafficking in controlled drugs would be imposed on Ridzuan and he would have accordingly been convicted of the capital charge.
#
# 95/131
# number of sentences found: 241
# number of candidate sentences found: 1
# qn: was public prosecutor's appeal dismissed?
# predicted sent: An example of a case where a criminal reference may be inappropriately brought and accordingly dismissed is Mohammad Faizal bin Sabtu v PP [2013] 2 SLR 141, where this court dismissed two criminal motions on two separate questions of law because, amongst other reasons, the court below had not made a final ruling or imposed a sentence and allowing the motions in those circumstances “would lead to an unnecessary and unacceptable disruption to the final disposal of both matters” (at [27]).
#
# 96/131
# number of sentences found: 196
# number of candidate sentences found: 2
# qn: was public prosecutor's appeal dismissed?
# predicted sent: This appeal neatly illustrated this principle – while there were certain gaps in the Respondent’s defence, especially given the fact that there was no objective or corroborating evidence from another party in support of the Respondent’s defence, we were not satisfied that the Judge was plainly wrong in his findings and therefore dismissed the appeal.
#
# 97/131
# number of sentences found: 310
# number of candidate sentences found: 4
# qn: was Devendran a/l Supramaniam's appeal dismissed?
# predicted sent: The Judge therefore convicted the Appellant on the charge of importing a controlled drug into Singapore.
#
# 98/131
# number of sentences found: 374
# number of candidate sentences found: 1
# qn: was public prosecutor's appeal dismissed?
# predicted sent: Accordingly, we allow the appeal, and convict the Respondent on the charge preferred against him.
#
# 99/131
# number of sentences found: 112
# number of candidate sentences found: 1
# qn: was Quek Hock Lye's appeal dismissed?
# predicted sent: The Judge proceeded to examine the evidence against the Applicant on the amended charge and found that there was sufficient evidence to prove the Applicant’s guilt beyond a reasonable doubt.
#
# 100/131
# number of sentences found: 399
# number of candidate sentences found: 1
# qn: was ABDUL KAHAR BIN OTHMAN's appeal dismissed?
# predicted sent: The Judge convicted the Appellant of both charges as he was satisfied that the Prosecution had proved beyond reasonable doubt that the Appellant “was possessing diamorphine for the purpose of trafficking” (see Abdul Kahar (Conviction) at [15]).
#
# 101/131
# number of sentences found: 414
# number of candidate sentences found: 4
# qn: was MASOUD RAHIMI BIN MEHRZAD's appeal dismissed?
# predicted sent: In order to make out the charge against Masoud, three elements had to be established (a) possession of the diamorphine (which may be proved or presumed), (b) knowledge of the diamorphine (which may be proved or presumed) and (c) proof that the possession of the diamorphine was for the purpose of trafficking.
#
# 102/131
# number of sentences found: 414
# number of candidate sentences found: 4
# qn: was MOGAN RAJ TERAPASISAMY's appeal dismissed?
# predicted sent: The Judge found that the charges against the appellants were established beyond reasonable doubt.
#
# 103/131
# number of sentences found: 646
# number of candidate sentences found: 1
# qn: was Harven a/l Segar's appeal dismissed?
# predicted sent: We therefore allow the appeal and acquit the Appellant of all the charges brought against him.
#
# 104/131
# number of sentences found: 530
# number of candidate sentences found: 3
# qn: was NORASHAREE BIN GOUS's appeal dismissed?
# predicted sent: We therefore agree with the Judge that the Prosecution’s case against Norasharee, similarly with its case against Kalwant, was proved beyond reasonable doubt.
#
# 105/131
# number of sentences found: 530
# number of candidate sentences found: 3
# qn: was KALWANT SINGH A/L JOGINDAR SINGH's appeal dismissed?
# predicted sent: Thus, the court in Chin Seow Noi v PP [1993] 3 SLR(R) 566 (“Chin Seow Noi”) held that s 30 of the Evidence Act (Cap 97, 1990 Rev Ed) (“EA 1990”), which is the predecessor of s 258(5) of the CPC, permitted the Court to convict X solely on the basis of Y’s confession, provided that the evidence emanating from Y’s confession satisfied the court beyond reasonable doubt of X’s guilt (at [84] per Yong Pung How CJ).
#
# 106/131
# number of sentences found: 384
# number of candidate sentences found: 10
# qn: was HISHAMRUDIN BIN MOHD's appeal dismissed?
# predicted sent: This is an appeal by an offender (“the Appellant”) against his conviction and sentence on two charges of trafficking in diamorphine under s 5(1)(a), read with s 5(2), of the Misuse of Drugs Act (Cap 185, 2008 Rev Ed) (“the MDA”).
#
# 107/131
# number of sentences found: 664
# number of candidate sentences found: 2
# qn: was Ali bin Mohamad Bahashwan's appeal dismissed?
# predicted sent: For an accused person to be convicted on a charge of abetting another in a conspiracy to traffic in drugs, it is necessary, Chong JA held, for the Prosecution to prove beyond a reasonable doubt that the accused intended those drugs to be passed to a third party.
#
# 108/131
# number of sentences found: 664
# number of candidate sentences found: 2
# qn: was Selamat bin Paki's appeal dismissed?
# predicted sent: For an accused person to be convicted on a charge of abetting another in a conspiracy to traffic in drugs, it is necessary, Chong JA held, for the Prosecution to prove beyond a reasonable doubt that the accused intended those drugs to be passed to a third party.
#
# 109/131
# number of sentences found: 664
# number of candidate sentences found: 2
# qn: was Ragunath Nair a/l Janartanan's appeal dismissed?
# predicted sent: For an accused person to be convicted on a charge of abetting another in a conspiracy to traffic in drugs, it is necessary, Chong JA held, for the Prosecution to prove beyond a reasonable doubt that the accused intended those drugs to be passed to a third party.
#
# 110/131
# number of sentences found: 438
# number of candidate sentences found: 3
# qn: was Mui Jia Jun's appeal dismissed?
# predicted sent: It appeared from the last-mentioned submission by the Prosecution that, having conceded that there was a reasonable doubt as to whether the first facet of its case was made out, it was advancing the Alternative Case (as we have defined it at [7] above) to uphold the Appellant’s conviction.
#
# 111/131
# number of sentences found: 260
# number of candidate sentences found: 3
# qn: was Zainal bin Hamad's appeal dismissed?
# predicted sent: On appeal, the Court of Appeal considered and approved Low Kok Wai for the proposition that since the Prosecution had relied on the presumption under s 17 of the MDA, it could not also rely on any other presumptions pertaining to possession (such as ss 18(1) and 21) and thus had to prove the fact of possession beyond reasonable doubt (at [42]–[44]).
#
# 112/131
# number of sentences found: 260
# number of candidate sentences found: 3
# qn: was Rahmat bin Karimon's appeal dismissed?
# predicted sent: Ultimately, it made no difference to the outcome in this case; we agreed with the Judge that all three elements of the offence in relation to Zainal were proved on the evidence before us and that the presumptions under ss 17 and 18 could also apply on either basis of running the case, namely, by proving the facts of knowledge and possession and invoking the presumption of trafficking, or by invoking the presumption of possession and/or knowledge and proving that such possession was for the purpose of trafficking; and, having analysed each of the scenarios in which the relevant presumptions were properly invoked, we were satisfied they were not rebutted.
#
# 113/131
# number of sentences found: 35
# number of candidate sentences found: 4
# qn: was Mohd Aziz bin Hussain's appeal dismissed?
# predicted sent: On that basis, the elements of possession and knowledge were satisfied.
#
# 114/131
# number of sentences found: 576
# number of candidate sentences found: 2
# qn: was Zainudin bin Mohamed's appeal dismissed?
# predicted sent: Given the circumstances, the Judge held at [66] that the charge against the Appellant had been proved beyond reasonable doubt.
#
# 115/131
# number of sentences found: 724
# number of candidate sentences found: 1
# qn: was Mohamed Af's appeal dismissed?
# predicted sent: Fadzli was convicted on Charge A and Affandi was convicted on Charge E. The Judge acquitted the appellants of one non-capital charge each (ie, Charges D and G) as he found that they were not proved beyond reasonable doubt.
#
# 116/131
# number of sentences found: 724
# number of candidate sentences found: 1
# qn: was Mohamad Fadzli bin Ahmad's appeal dismissed?
# predicted sent: Fadzli was convicted on Charge A and Affandi was convicted on Charge E. The Judge acquitted the appellants of one non-capital charge each (ie, Charges D and G) as he found that they were not proved beyond reasonable doubt.
#
# 117/131
# number of sentences found: 511
# number of candidate sentences found: 1
# qn: was Ramesh a/l Perumal's appeal dismissed?
# predicted sent: As we shall explain, we find that this element of the offence was not in fact proved beyond reasonable doubt, and therefore the appellant may only be convicted of the lesser charge of possession.
#
# 118/131
# number of sentences found: 511
# number of candidate sentences found: 1
# qn: was C's appeal dismissed?
# predicted sent: As we shall explain, we find that this element of the offence was not in fact proved beyond reasonable doubt, and therefore the appellant may only be convicted of the lesser charge of possession.
#
# 119/131
# number of sentences found: 467
# number of candidate sentences found: 1
# qn: was Adili Chibuike Ejike's appeal dismissed?
# predicted sent: Accordingly, we allow the appeal against conviction and acquit the Appellant of the charge against him.
#
# 120/131
# number of sentences found: 431
# number of candidate sentences found: 2
# qn: was Moad Fadzir bin Mustaffa's appeal dismissed?
# predicted sent: Moad Fadzir, Zuraimy as well as the Prosecution appealed against the Judge’s decision, resulting in the following three appeals before us:
# (a)     in Criminal Appeal No 12 of 2019 (“CCA 12”), Moad Fadzir appealed against his conviction and sentence, disputing the elements of knowledge of the nature of the drugs and possession of the drugs for the purpose of trafficking;
# (b)     in Criminal Appeal No 14 of 2019 (“CCA 14”), the Prosecution appealed against the acquittal of Zuraimy on the original trafficking charge; and
# (c)     in Criminal Appeal No 18 of 2019 (“CCA 18”), Zuraimy appealed against his sentence on the amended charge, on the ground that it is manifestly excessive.
#
# 121/131
# number of sentences found: 431
# number of candidate sentences found: 2
# qn: was Zuraimy bin Musa's appeal dismissed?
# predicted sent: Moad Fadzir, Zuraimy as well as the Prosecution appealed against the Judge’s decision, resulting in the following three appeals before us:
# (a)     in Criminal Appeal No 12 of 2019 (“CCA 12”), Moad Fadzir appealed against his conviction and sentence, disputing the elements of knowledge of the nature of the drugs and possession of the drugs for the purpose of trafficking;
# (b)     in Criminal Appeal No 14 of 2019 (“CCA 14”), the Prosecution appealed against the acquittal of Zuraimy on the original trafficking charge; and
# (c)     in Criminal Appeal No 18 of 2019 (“CCA 18”), Zuraimy appealed against his sentence on the amended charge, on the ground that it is manifestly excessive.
#
# 122/131
# number of sentences found: 482
# number of candidate sentences found: 1
# qn: was Han Fang Guan's appeal dismissed?
# predicted sent: For the reasons that follow, we accept that there is a reasonable doubt as to whether Han had ordered diamorphine from Lao Ban, and we therefore allow this appeal and acquit Han of the charge against him as it currently stands on the basis that the Prosecution has failed to prove beyond a reasonable doubt that he intended to possess the diamorphine contained in D1B.
#
# 123/131
# number of sentences found: 482
# number of candidate sentences found: 1
# qn: was Khor Chong Seng's appeal dismissed?
# predicted sent: For the reasons that follow, we accept that there is a reasonable doubt as to whether Han had ordered diamorphine from Lao Ban, and we therefore allow this appeal and acquit Han of the charge against him as it currently stands on the basis that the Prosecution has failed to prove beyond a reasonable doubt that he intended to possess the diamorphine contained in D1B.
#
# 124/131
# number of sentences found: 580
# number of candidate sentences found: 1
# qn: was Mohammad Farid bin Batra's appeal dismissed?
# predicted sent: We therefore dismissed CM 5/2017 and Ranjit’s appeal against conviction and sentence at the earlier hearing.
#
# 125/131
# number of sentences found: 580
# number of candidate sentences found: 1
# qn: was Ranjit Singh Gill Manjeet Singh's appeal dismissed?
# predicted sent: We therefore dismissed CM 5/2017 and Ranjit’s appeal against conviction and sentence at the earlier hearing.
#
# 126/131
# number of sentences found: 678
# number of candidate sentences found: 3
# qn: was Muhammad Nabill bin Mohd Fuad's appeal dismissed?
# predicted sent: There, we explained that embedded within the concept of proof beyond a reasonable doubt is the Prosecution’s legal burden to prove the charge against the accused person beyond a reasonable doubt and its evidential burden to adduce sufficient evidence to address facts that have been put in issue (see GCK at [130] and [132]).
#
# 127/131
# number of sentences found: 524
# number of candidate sentences found: 3
# qn: was Mohammad Azli bin Mohammad Salleh's appeal dismissed?
# predicted sent: As we saw no reason to doubt that Roszaidi knowingly possessed the Drugs and had trafficked in them by delivering them to Azidah, we affirmed his conviction and dismissed this part of his appeal.
#
# 128/131
# number of sentences found: 524
# number of candidate sentences found: 3
# qn: was Roszaidi bin Osman's appeal dismissed?
# predicted sent: As we saw no reason to doubt that Roszaidi knowingly possessed the Drugs and had trafficked in them by delivering them to Azidah, we affirmed his conviction and dismissed this part of his appeal.
#
# 129/131
# number of sentences found: 775
# number of candidate sentences found: 2
# qn: was Saravanan C's appeal dismissed?
# predicted sent: This appeal offers us the opportunity to revisit the judicial interpretations of the definition and classification of “cannabis” and “cannabis mixture” enacted in the MDA, and to determine, in that light, whether the elements of both the Importation of Cannabis Charge and the Importation of Cannabis Mixture Charge have been proved beyond reasonable doubt.
#
# 130/131
# number of sentences found: 631
# number of candidate sentences found: 1
# qn: was Mohammad Rizwan bin Akbar Husain's appeal dismissed?
# predicted sent: We therefore agree that the charge against Saminathan was proved beyond reasonable doubt and we affirm the Judge’s decision to convict him.
#
# 131/131
# number of sentences found: 631
# number of candidate sentences found: 1
# qn: was Saminathan Selvaraju's appeal dismissed?
# predicted sent: We therefore agree that the charge against Saminathan was proved beyond reasonable doubt and we affirm the Judge’s decision to convict him.
# 131

# %%
# display length of each predicted answer in terms of no. of tokens.

tokenized_answers = list()
for sent in preds:
    tokens = word_tokenize(sent)
    tokenized_answers.append(tokens)

lengths = [len(answer) for answer in tokenized_answers]
print(f"min sent length: {min(lengths)}")
print(f"max sent length {max(lengths)}")
# Out:
# min sent length: 6
# max sent length 162

# %%
path = input('enter path to save csv file:\n')
to_save = pd.DataFrame()
to_save.insert(0, "unique_ref", appeals_df['unique_ref'].values)
to_save.insert(1, "predicted_answer", preds)
to_save.to_csv(path)
# Out:
# enter path to save csv file:
#  data/appeals_base.csv
