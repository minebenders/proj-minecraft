# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### Pull out cases.

# %%
'''
Set up the cases dataframe from the cases json file.
(based on glowsplint's test_output.py code)
'''
json_file = input("enter path to json file of cases.\n")
output_df = pd.read_json(json_file)

court_map = {
    'High Court': 'SGHC',
    'Court of Appeal': 'SGCA',
    'District Court': 'SGDC',
    'Court of Criminal Appeal': 'SGCA'
}

output_df['Court'] = output_df.Court.map(court_map)
ref_columns = {
    0: 'refSLR',
    1: 'ref'
}

# Split reference into SLR reference and normal reference
output_df[list(ref_columns.values())] = pd.DataFrame(
    output_df.reference.apply(pd.Series)).rename(columns=ref_columns)
ref_na = output_df['ref'].isna()
output_df.loc[ref_na, 'ref'], output_df.loc[ref_na,'refSLR'] = output_df.refSLR[ref_na], np.nan
output_df.drop('reference', axis=1, inplace=True)

# retain the ordered list of parties in one column, before exploding output_df['parties'] next.
output_df = output_df.assign(listed_parties=output_df.parties)

# Construct the unique reference
exploded_output = output_df.explode('parties')
output_df = exploded_output.loc[exploded_output.parties.str.lower(
) != "public prosecutor"].copy()
output_df['unique_ref'] = output_df['ref'] + \
    ' ' + output_df['parties']
output_df.unique_ref = output_df.unique_ref.str.upper().str.replace(
    "AND ANOTHER", "").str.replace("AND OTHERS", "").str.replace(' +', ' ').str.strip()
output_df = output_df[['unique_ref', 'case_id', 'date', 'Court',
                                 'coram', 'counsel', 'listed_parties', 'parties', 'paragraphs']]
output_df.rename(columns={'parties': 'accused'}, inplace=True)
# Out:
# enter path to json file of cases.
#  data/murder_cases.json

# %%
display(output_df)
print(f"no. of cases: {len(output_df)}")
# Out:
#                                           unique_ref  \
# 0                          [1983] SGHC 24 ADRIAN LIM
# 0                        [1983] SGHC 24 TAN MUI CHAO
# 0                        [1983] SGHC 24 HOC KAH HONG
# 1                      [2007] SGHC 86 KWONG KOK HING
# 2        [2008] SGHC 120 DANIEL VIJAY S/O KATHERASAN
# 2   [2008] SGHC 120 CHRISTOPHER SAMSON S/O ANPALAGAN
# 2             [2008] SGHC 120 NAKAMUTHU BALAKRISHNAN
# 3                             [2008] SGHC 22 BAROKAH
# 4                             [2009] SGHC 46 BAROKAH
# 5                       [2010] SGCA 37 ONG PANG SIEW
# 6                  [2010] SGHC 131 ASTRO BIN JAKARIA
# 7                  [2010] SGHC 212 GALING ANAK KUJAT
# 8                                 [2010] SGHC 82 AFR
# 9         [2012] SGCA 44 PATHIP SELVAN S/O SUGUMARAN
# 10                      [2012] SGHC 238 WANG ZHIJIAN
# 11                        [2013] SGHC 251 KHO JABING
# 12                       [2014] SGCA 58 WANG ZHIJIAN
# 13                       [2014] SGHC 23 WANG WENFENG
# 14                          [2015] SGCA 1 KHO JABING
# 15          [2015] SGHC 292 SUTHERSON, SUJAY SOLOMON
# 16                         [2016] SGCA 21 JABING KHO
# 17                [2016] SGCA 62 ROSMAN BIN ABDULLAH
# 18                                [2017] SGCA 69 BDB
# 19                 [2017] SGCA 7 MICHEAL ANAK GARING
# 20                 [2017] SGCA 9 ISKANDAR BIN RAHMAT
# 21                   [2017] SGHC 29 RASHEED MUHAMMAD
# 21                      [2017] SGHC 29 RAMZAN RIZWAN
# 22                      [2017] SGHC 307 P MAGESWARAN
# 23                      [2018] SGCA 30 CHIA KEE CHEN
# 24                               [2018] SGHC 135 BPK
# 25                       [2019] SGCA 22 P MAGESWARAN
# 26                      [2019] SGCA 44 CHAN LIE SIAN
#
#                                               case_id       date Court  \
# 0                         Criminal Case No 23 of 1982 1983-05-25  SGHC
# 0                         Criminal Case No 23 of 1982 1983-05-25  SGHC
# 0                         Criminal Case No 23 of 1982 1983-05-25  SGHC
# 1                                          CC 13/2007 2007-05-30  SGHC
# 2                                          CC 16/2007 2008-07-28  SGHC
# 2                                          CC 16/2007 2008-07-28  SGHC
# 2                                          CC 16/2007 2008-07-28  SGHC
# 3                                          CC 23/2007 2008-02-11  SGHC
# 4                                          CC 23/2007 2009-02-26  SGHC
# 5                        Criminal Appeal No 4 of 2009 2010-11-08  SGCA
# 6                          Criminal Case No 6 of 2010 2010-04-29  SGHC
# 7                         Criminal Case No 31 of 2009 2010-07-30  SGHC
# 8                         Criminal Case No 44 of 2009 2010-03-17  SGHC
# 9                       Criminal Appeal No 24 of 2010 2012-08-15  SGCA
# 10                         Criminal Case No 3 of 2011 2012-11-30  SGHC
# 11                        Criminal Case No 31 of 2009 2013-11-18  SGHC
# 12      Criminal Appeals Nos 12 of 2012 and 4 of 2013 2014-11-28  SGCA
# 13                         Criminal Case No 4 of 2011 2014-02-07  SGHC
# 14                       Criminal Appeal No 6 of 2013 2015-01-14  SGCA
# 15                        Criminal Case No 31 of 2015 2015-11-06  SGHC
# 16                      Criminal Motion No 24 of 2015 2016-04-05  SGCA
# 17                      Criminal Appeal No 31 of 2015 2016-11-21  SGCA
# 18                      Criminal Appeal No 26 of 2016 2017-11-29  SGCA
# 19              Criminal Appeals Nos 9 and 11 of 2015 2017-02-27  SGCA
# 20  Criminal Appeal No 39 of 2015, Criminal Motion... 2017-02-03  SGCA
# 21                        Criminal Case No 60 of 2016 2017-02-17  SGHC
# 21                        Criminal Case No 60 of 2016 2017-02-17  SGHC
# 22                        Criminal Case No 62 of 2016 2017-11-29  SGHC
# 23             Criminal Appeals Nos 40 and 41 of 2017 2018-06-27  SGCA
# 24                        Criminal Case No 10 of 2017 2018-06-04  SGHC
# 25             Criminal Appeals Nos 36 and 37 of 2017 2019-04-11  SGCA
# 26                      Criminal Appeal No 25 of 2017 2019-07-30  SGCA
#
#                                                 coram  \
# 0                           [Chua, J, Sinnathuray, J]
# 0                           [Chua, J, Sinnathuray, J]
# 0                           [Chua, J, Sinnathuray, J]
# 1                                   [Choo Han Teck J]
# 2                                  [Tay Yong Kwang J]
# 2                                  [Tay Yong Kwang J]
# 2                                  [Tay Yong Kwang J]
# 3                                  [Tay Yong Kwang J]
# 4                                  [Tay Yong Kwang J]
# 5   [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 6                                   [Chan Seng Onn J]
# 7                                   [Kan Ting Chiu J]
# 8                                    [Lee Seiu Kin J]
# 9   [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 10                                  [Chan Seng Onn J]
# 11                                 [Tay Yong Kwang J]
# 12  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 13                                   [Lee Seiu Kin J]
# 14  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 15                                [Hoo Sheau Peng JC]
# 16  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 17  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 18  [Sundaresh Menon CJ, Tay Yong Kwang JA, Steven...
# 19  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 20  [Sundaresh Menon CJ, Chao Hick Tin JA, Andrew ...
# 21                                  [Choo Han Teck J]
# 21                                  [Choo Han Teck J]
# 22                                 [Hoo Sheau Peng J]
# 23  [Sundaresh Menon CJ, Judith Prakash JA, Tay Yo...
# 24                                     [Woo Bih Li J]
# 25  [Judith Prakash JA, Steven Chong JA, Woo Bih L...
# 26  [Sundaresh Menon CJ, Andrew Phang Boon Leong J...
#
#                                               counsel  \
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 1   {'prosecution': ['Francis Ng', 'Luke Tang', 'J...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 3   {'prosecution': ['Amarjit Singh', 'Stella Tan'...
# 4   {'prosecution': ['Amarjit Singh', 'Stella Tan'...
# 5   {'prosecution': ['Prem Raj', 'Bala Reddy'], 'd...
# 6   {'prosecution': ['Cassandra Cheong', 'Ng Cheng...
# 7   {'prosecution': ['Leong Wing Tuck', 'Gordon Oh...
# 8   {'prosecution': ['Cheng Howe Ming Winston', 'S...
# 9   {'prosecution': ['David Khoo', 'Dennis Tan'], ...
# 10  {'prosecution': ['Hay Hung Chun', 'Eunice Chon...
# 11  {'prosecution': ['Lee Lit Cheng', 'Teo Lu Jia'...
# 12  {'prosecution': ['Hay Hung Chun', 'Timotheus K...
# 13  {'prosecution': ['Ilona Tan', 'Kelly Ho', 'Bal...
# 14  {'prosecution': ['Hay Hung Chun', 'Teo Lu Jia'...
# 15  {'prosecution': ['Kumaresan Gohulabalan', 'Elt...
# 16  {'prosecution': ['Francis Ng', 'Marshall Lim',...
# 17  {'prosecution': ['Chan Yi Cheng', 'Ng Cheng Th...
# 18  {'prosecution': ['Soh Weiqi', 'Tan Zhongshan',...
# 19  {'prosecution': ['in Criminal Appeal No 9 of 2...
# 20  {'prosecution': ['Mansoor Amir', 'Lee Lit Chen...
# 21  {'prosecution': ['Ong Luan Tze', 'Houston Joha...
# 21  {'prosecution': ['Ong Luan Tze', 'Houston Joha...
# 22  {'prosecution': ['Kelly Ho Yan-Qing', 'Wong Ko...
# 23  {'prosecution': ['Hri Kumar Nair SC', 'in Crim...
# 24  {'prosecution': ['Bhajanvir Singh', 'Lim Ai Ju...
# 25  {'prosecution': ['in Criminal Appeal No 36 of ...
# 26  {'prosecution': ['April Phang', 'Sarah Shi'], ...
#
#                                        listed_parties  \
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 1                 [Public Prosecutor, Kwong Kok Hing]
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 3                        [Public Prosecutor, Barokah]
# 4                        [Public Prosecutor, Barokah]
# 5                  [Ong Pang Siew, Public Prosecutor]
# 6              [Public Prosecutor, Astro bin Jakaria]
# 7   [Public Prosecutor, Galing Anak Kujat and anot...
# 8                            [Public Prosecutor, AFR]
# 9    [Pathip Selvan s/o Sugumaran, Public Prosecutor]
# 10                  [Public Prosecutor, Wang Zhijian]
# 11                    [Public Prosecutor, Kho Jabing]
# 12                  [Public Prosecutor, Wang Zhijian]
# 13                  [Public Prosecutor, Wang Wenfeng]
# 14                    [Public Prosecutor, Kho Jabing]
# 15      [Public Prosecutor, Sutherson, Sujay Solomon]
# 16                    [Jabing Kho, Public Prosecutor]
# 17           [ROSMAN BIN ABDULLAH, PUBLIC PROSECUTOR]
# 18                           [Public Prosecutor, BDB]
# 19           [Micheal Anak Garing, Public Prosecutor]
# 20           [Iskandar Bin Rahmat, Public Prosecutor]
# 21  [Public Prosecutor, Rasheed Muhammad, Ramzan R...
# 21  [Public Prosecutor, Rasheed Muhammad, Ramzan R...
# 22                  [Public Prosecutor, P Mageswaran]
# 23                 [Public Prosecutor, Chia Kee Chen]
# 24                           [Public Prosecutor, BPK]
# 25                  [Public Prosecutor, P Mageswaran]
# 26                 [Chan Lie Sian, Public Prosecutor]
#
#                              accused  \
# 0                         Adrian Lim
# 0                       Tan Mui Chao
# 0                       Hoc Kah Hong
# 1                     Kwong Kok Hing
# 2        Daniel Vijay s/o Katherasan
# 2   Christopher Samson s/o Anpalagan
# 2             Nakamuthu Balakrishnan
# 3                            Barokah
# 4                            Barokah
# 5                      Ong Pang Siew
# 6                  Astro bin Jakaria
# 7      Galing Anak Kujat and another
# 8                                AFR
# 9        Pathip Selvan s/o Sugumaran
# 10                      Wang Zhijian
# 11                        Kho Jabing
# 12                      Wang Zhijian
# 13                      Wang Wenfeng
# 14                        Kho Jabing
# 15          Sutherson, Sujay Solomon
# 16                        Jabing Kho
# 17               ROSMAN BIN ABDULLAH
# 18                               BDB
# 19               Micheal Anak Garing
# 20               Iskandar Bin Rahmat
# 21                  Rasheed Muhammad
# 21                     Ramzan Rizwan
# 22                      P Mageswaran
# 23                     Chia Kee Chen
# 24                               BPK
# 25                      P Mageswaran
# 26                     Chan Lie Sian
#
#                                            paragraphs
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 1   {'1': 'On 14 September 2006 the accused was qu...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 3   {'1': 'The accused is an Indonesian woman born...
# 4   {'1': 'The precursor to this judgment is PP v ...
# 5   {'1': 'This is the appeal by Ong Pang Siew (“t...
# 6   {'1': 'The accused, Astro bin Jakaria, is char...
# 7   {'1': 'On the night of 17 February 2008, two p...
# 8   {'1': 'The deceased, described as a lively gir...
# 9   {'1': 'This is a tragic case of a young couple...
# 10  {'1': 'The accused, Wang Zhijian (“Wang”), is ...
# 11  {'1': 'Jabing Kho (“the convicted person”) and...
# 12  {'1': 'This was a tragic case involving the de...
# 13  {'1': 'On 20 September 2011, Wang Wenfeng (“Wa...
# 14  {'1': 'In PP v Galing Anak Kujat [2010] SGHC 2...
# 15  {'1': 'The accused, Sujay Solomon Sutherson, w...
# 16  {'1': 'In our recent decision in The Royal Ban...
# 17  {'1': 'The appellant (“the Appellant”) had bee...
# 18  {'1': 'This appeal stemmed from a tragic case....
# 19  {'1': 'Micheal Anak Garing (“MAG”) and Tony An...
# 20  {'1': 'This is an appeal against the convictio...
# 21  {'1': 'On 11 June 2014, an 81-year-old man, Ta...
# 21  {'1': 'On 11 June 2014, an 81-year-old man, Ta...
# 22  {'1': 'The accused claimed trial to the follow...
# 23  {'1': 'The present appeals arise out of the bl...
# 24  {'1': 'On 14 February 2018, the accused (“the ...
# 25  {'1': 'These appeals arose from the decision o...
# 26  {'1': 'The present appeal arises out of a brut...
# no. of cases: 32

# %%
output_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Pull out appeals.

# %%
# filter out cases that are definitely appeal cases into a new dataframe.
appeals_indices = []
for i in range(len(output_df)):
    if 'SGCA' in output_df.iloc[i]["Court"]:
        appeals_indices.append(i)

appeals_df = output_df.iloc[appeals_indices].reset_index(drop=True)
display(appeals_df.head())
print(f"no. of cases: {len(appeals_df)}")
# Out:
#                                    unique_ref       date Court  \
# 0                [2010] SGCA 37 ONG PANG SIEW 2010-11-08  SGCA
# 1  [2012] SGCA 44 PATHIP SELVAN S/O SUGUMARAN 2012-08-15  SGCA
# 2                 [2014] SGCA 58 WANG ZHIJIAN 2014-11-28  SGCA
# 3                    [2015] SGCA 1 KHO JABING 2015-01-14  SGCA
# 4                   [2016] SGCA 21 JABING KHO 2016-04-05  SGCA
#
#                                                coram  \
# 0  [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 1  [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 2  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 3  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 4  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
#
#                                              counsel  \
# 0  {'prosecution': ['Prem Raj', 'Bala Reddy'], 'd...
# 1  {'prosecution': ['David Khoo', 'Dennis Tan'], ...
# 2  {'prosecution': ['Hay Hung Chun', 'Timotheus K...
# 3  {'prosecution': ['Hay Hung Chun', 'Teo Lu Jia'...
# 4  {'prosecution': ['Francis Ng', 'Marshall Lim',...
#
#                                      listed_parties  \
# 0                [Ong Pang Siew, Public Prosecutor]
# 1  [Pathip Selvan s/o Sugumaran, Public Prosecutor]
# 2                 [Public Prosecutor, Wang Zhijian]
# 3                   [Public Prosecutor, Kho Jabing]
# 4                   [Jabing Kho, Public Prosecutor]
#
#                        accused  \
# 0                Ong Pang Siew
# 1  Pathip Selvan s/o Sugumaran
# 2                 Wang Zhijian
# 3                   Kho Jabing
# 4                   Jabing Kho
#
#                                           paragraphs
# 0  {'1': 'This is the appeal by Ong Pang Siew (“t...
# 1  {'1': 'This is a tragic case of a young couple...
# 2  {'1': 'This was a tragic case involving the de...
# 3  {'1': 'In PP v Galing Anak Kujat [2010] SGHC 2...
# 4  {'1': 'In our recent decision in The Royal Ban...
# no. of cases: 12

# %%
len(appeals_df)
# Out:
# 12

# %%
# find the appellant of each case, and put into df.
appellants = list()
for i in range(len(appeals_df)):
    if appeals_df.iloc[i]['listed_parties'][0].lower() != "public prosecutor":
        appellant = appeals_df.iloc[i]['accused']
        and_index = appellant.find("and ")
        if and_index != -1:
            # if 'X and others' then cut away ' and others'
            appellant = appellant[0:and_index - 1]
    else:
        appellant = "public prosecutor"
    appellants.append(appellant)
print(appellants)
appeals_df = appeals_df.assign(appellant=appellants)
appeals_df = appeals_df.reset_index(drop=True)
appeals_df.head()
# Out:
# ['Ong Pang Siew', 'Pathip Selvan s/o Sugumaran', 'public prosecutor', 'public prosecutor', 'Jabing Kho', 'ROSMAN BIN ABDULLAH', 'public prosecutor', 'Micheal Anak Garing', 'Iskandar Bin Rahmat', 'public prosecutor', 'public prosecutor', 'Chan Lie Sian']
#                                    unique_ref       date Court  \
# 0                [2010] SGCA 37 ONG PANG SIEW 2010-11-08  SGCA
# 1  [2012] SGCA 44 PATHIP SELVAN S/O SUGUMARAN 2012-08-15  SGCA
# 2                 [2014] SGCA 58 WANG ZHIJIAN 2014-11-28  SGCA
# 3                    [2015] SGCA 1 KHO JABING 2015-01-14  SGCA
# 4                   [2016] SGCA 21 JABING KHO 2016-04-05  SGCA
#
#                                                coram  \
# 0  [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 1  [Chan Sek Keong CJ, Andrew Phang Boon Leong JA...
# 2  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 3  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
# 4  [Chao Hick Tin JA, Andrew Phang Boon Leong JA,...
#
#                                              counsel  \
# 0  {'prosecution': ['Prem Raj', 'Bala Reddy'], 'd...
# 1  {'prosecution': ['David Khoo', 'Dennis Tan'], ...
# 2  {'prosecution': ['Hay Hung Chun', 'Timotheus K...
# 3  {'prosecution': ['Hay Hung Chun', 'Teo Lu Jia'...
# 4  {'prosecution': ['Francis Ng', 'Marshall Lim',...
#
#                                      listed_parties  \
# 0                [Ong Pang Siew, Public Prosecutor]
# 1  [Pathip Selvan s/o Sugumaran, Public Prosecutor]
# 2                 [Public Prosecutor, Wang Zhijian]
# 3                   [Public Prosecutor, Kho Jabing]
# 4                   [Jabing Kho, Public Prosecutor]
#
#                        accused  \
# 0                Ong Pang Siew
# 1  Pathip Selvan s/o Sugumaran
# 2                 Wang Zhijian
# 3                   Kho Jabing
# 4                   Jabing Kho
#
#                                           paragraphs  \
# 0  {'1': 'This is the appeal by Ong Pang Siew (“t...
# 1  {'1': 'This is a tragic case of a young couple...
# 2  {'1': 'This was a tragic case involving the de...
# 3  {'1': 'In PP v Galing Anak Kujat [2010] SGHC 2...
# 4  {'1': 'In our recent decision in The Royal Ban...
#
#                      appellant
# 0                Ong Pang Siew
# 1  Pathip Selvan s/o Sugumaran
# 2            public prosecutor
# 3            public prosecutor
# 4                   Jabing Kho

# %%
path = input('enter path to save csv file:\n')
appeals_df[['unique_ref', 'Court', 'appellant', 'accused']].to_csv(path)
# Out:
# enter path to save csv file:
#  data/murder_cases_some_metadata.csv

# %% [markdown]
# ### Pull out trials.

# %%
# filter out cases that are definitely trial cases
trials_indices = []
for i in range(len(output_df)):
    if "criminal case" in output_df.iloc[i]["case_id"].lower() or \
    "cc " in output_df.iloc[i]["case_id"].lower() and \
    output_df.iloc[i]["Court"] != 'SGCA':
        trials_indices.append(i)
    elif output_df.iloc[i]["Court"] == 'SGDC':
        trials_indices.append(i)

trials_df = output_df.iloc[trials_indices]
display(trials_df)
print(f"no. of cases: {len(trials_df)}")
# Out:
#                                           unique_ref  \
# 0                          [1983] SGHC 24 ADRIAN LIM
# 0                        [1983] SGHC 24 TAN MUI CHAO
# 0                        [1983] SGHC 24 HOC KAH HONG
# 1                      [2007] SGHC 86 KWONG KOK HING
# 2        [2008] SGHC 120 DANIEL VIJAY S/O KATHERASAN
# 2   [2008] SGHC 120 CHRISTOPHER SAMSON S/O ANPALAGAN
# 2             [2008] SGHC 120 NAKAMUTHU BALAKRISHNAN
# 3                             [2008] SGHC 22 BAROKAH
# 4                             [2009] SGHC 46 BAROKAH
# 6                  [2010] SGHC 131 ASTRO BIN JAKARIA
# 7                  [2010] SGHC 212 GALING ANAK KUJAT
# 8                                 [2010] SGHC 82 AFR
# 10                      [2012] SGHC 238 WANG ZHIJIAN
# 11                        [2013] SGHC 251 KHO JABING
# 13                       [2014] SGHC 23 WANG WENFENG
# 15          [2015] SGHC 292 SUTHERSON, SUJAY SOLOMON
# 21                   [2017] SGHC 29 RASHEED MUHAMMAD
# 21                      [2017] SGHC 29 RAMZAN RIZWAN
# 22                      [2017] SGHC 307 P MAGESWARAN
# 24                               [2018] SGHC 135 BPK
#
#                         case_id       date Court                      coram  \
# 0   Criminal Case No 23 of 1982 1983-05-25  SGHC  [Chua, J, Sinnathuray, J]
# 0   Criminal Case No 23 of 1982 1983-05-25  SGHC  [Chua, J, Sinnathuray, J]
# 0   Criminal Case No 23 of 1982 1983-05-25  SGHC  [Chua, J, Sinnathuray, J]
# 1                    CC 13/2007 2007-05-30  SGHC          [Choo Han Teck J]
# 2                    CC 16/2007 2008-07-28  SGHC         [Tay Yong Kwang J]
# 2                    CC 16/2007 2008-07-28  SGHC         [Tay Yong Kwang J]
# 2                    CC 16/2007 2008-07-28  SGHC         [Tay Yong Kwang J]
# 3                    CC 23/2007 2008-02-11  SGHC         [Tay Yong Kwang J]
# 4                    CC 23/2007 2009-02-26  SGHC         [Tay Yong Kwang J]
# 6    Criminal Case No 6 of 2010 2010-04-29  SGHC          [Chan Seng Onn J]
# 7   Criminal Case No 31 of 2009 2010-07-30  SGHC          [Kan Ting Chiu J]
# 8   Criminal Case No 44 of 2009 2010-03-17  SGHC           [Lee Seiu Kin J]
# 10   Criminal Case No 3 of 2011 2012-11-30  SGHC          [Chan Seng Onn J]
# 11  Criminal Case No 31 of 2009 2013-11-18  SGHC         [Tay Yong Kwang J]
# 13   Criminal Case No 4 of 2011 2014-02-07  SGHC           [Lee Seiu Kin J]
# 15  Criminal Case No 31 of 2015 2015-11-06  SGHC        [Hoo Sheau Peng JC]
# 21  Criminal Case No 60 of 2016 2017-02-17  SGHC          [Choo Han Teck J]
# 21  Criminal Case No 60 of 2016 2017-02-17  SGHC          [Choo Han Teck J]
# 22  Criminal Case No 62 of 2016 2017-11-29  SGHC         [Hoo Sheau Peng J]
# 24  Criminal Case No 10 of 2017 2018-06-04  SGHC             [Woo Bih Li J]
#
#                                               counsel  \
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 0   {'prosecution': ['Glenn Knight assisted by Roy...
# 1   {'prosecution': ['Francis Ng', 'Luke Tang', 'J...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 2   {'prosecution': ['Amarjit Singh', 'Lee Cheow H...
# 3   {'prosecution': ['Amarjit Singh', 'Stella Tan'...
# 4   {'prosecution': ['Amarjit Singh', 'Stella Tan'...
# 6   {'prosecution': ['Cassandra Cheong', 'Ng Cheng...
# 7   {'prosecution': ['Leong Wing Tuck', 'Gordon Oh...
# 8   {'prosecution': ['Cheng Howe Ming Winston', 'S...
# 10  {'prosecution': ['Hay Hung Chun', 'Eunice Chon...
# 11  {'prosecution': ['Lee Lit Cheng', 'Teo Lu Jia'...
# 13  {'prosecution': ['Ilona Tan', 'Kelly Ho', 'Bal...
# 15  {'prosecution': ['Kumaresan Gohulabalan', 'Elt...
# 21  {'prosecution': ['Ong Luan Tze', 'Houston Joha...
# 21  {'prosecution': ['Ong Luan Tze', 'Houston Joha...
# 22  {'prosecution': ['Kelly Ho Yan-Qing', 'Wong Ko...
# 24  {'prosecution': ['Bhajanvir Singh', 'Lim Ai Ju...
#
#                                        listed_parties  \
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 0   [Public Prosecutor, Adrian Lim, Tan Mui Chao, ...
# 1                 [Public Prosecutor, Kwong Kok Hing]
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 2   [Public Prosecutor, Daniel Vijay s/o Katherasa...
# 3                        [Public Prosecutor, Barokah]
# 4                        [Public Prosecutor, Barokah]
# 6              [Public Prosecutor, Astro bin Jakaria]
# 7   [Public Prosecutor, Galing Anak Kujat and anot...
# 8                            [Public Prosecutor, AFR]
# 10                  [Public Prosecutor, Wang Zhijian]
# 11                    [Public Prosecutor, Kho Jabing]
# 13                  [Public Prosecutor, Wang Wenfeng]
# 15      [Public Prosecutor, Sutherson, Sujay Solomon]
# 21  [Public Prosecutor, Rasheed Muhammad, Ramzan R...
# 21  [Public Prosecutor, Rasheed Muhammad, Ramzan R...
# 22                  [Public Prosecutor, P Mageswaran]
# 24                           [Public Prosecutor, BPK]
#
#                              accused  \
# 0                         Adrian Lim
# 0                       Tan Mui Chao
# 0                       Hoc Kah Hong
# 1                     Kwong Kok Hing
# 2        Daniel Vijay s/o Katherasan
# 2   Christopher Samson s/o Anpalagan
# 2             Nakamuthu Balakrishnan
# 3                            Barokah
# 4                            Barokah
# 6                  Astro bin Jakaria
# 7      Galing Anak Kujat and another
# 8                                AFR
# 10                      Wang Zhijian
# 11                        Kho Jabing
# 13                      Wang Wenfeng
# 15          Sutherson, Sujay Solomon
# 21                  Rasheed Muhammad
# 21                     Ramzan Rizwan
# 22                      P Mageswaran
# 24                               BPK
#
#                                            paragraphs
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 0   {'1': '25 May 1983  ', '2': 'Before we give ou...
# 1   {'1': 'On 14 September 2006 the accused was qu...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 2   {'1': 'The first accused is Daniel Vijay s/o K...
# 3   {'1': 'The accused is an Indonesian woman born...
# 4   {'1': 'The precursor to this judgment is PP v ...
# 6   {'1': 'The accused, Astro bin Jakaria, is char...
# 7   {'1': 'On the night of 17 February 2008, two p...
# 8   {'1': 'The deceased, described as a lively gir...
# 10  {'1': 'The accused, Wang Zhijian (“Wang”), is ...
# 11  {'1': 'Jabing Kho (“the convicted person”) and...
# 13  {'1': 'On 20 September 2011, Wang Wenfeng (“Wa...
# 15  {'1': 'The accused, Sujay Solomon Sutherson, w...
# 21  {'1': 'On 11 June 2014, an 81-year-old man, Ta...
# 21  {'1': 'On 11 June 2014, an 81-year-old man, Ta...
# 22  {'1': 'The accused claimed trial to the follow...
# 24  {'1': 'On 14 February 2018, the accused (“the ...
# no. of cases: 20

# %%
trial_cases = set(trials_df['unique_ref'].values)
appeal_cases = set(appeals_df['unique_ref'].values)
all_cases = set(output_df['unique_ref'].values)
leftover = all_cases - (trial_cases | appeal_cases)
if len(leftover) == 0:
    print('all cases found have been identified as either trial or appeal.')
# Out:
# all cases found have been identified as either trial or appeal.

# %%
trial_cases
# Out:
# {'[1983] SGHC 24 ADRIAN LIM',
#  '[1983] SGHC 24 HOC KAH HONG',
#  '[1983] SGHC 24 TAN MUI CHAO',
#  '[2007] SGHC 86 KWONG KOK HING',
#  '[2008] SGHC 120 CHRISTOPHER SAMSON S/O ANPALAGAN',
#  '[2008] SGHC 120 DANIEL VIJAY S/O KATHERASAN',
#  '[2008] SGHC 120 NAKAMUTHU BALAKRISHNAN',
#  '[2008] SGHC 22 BAROKAH',
#  '[2009] SGHC 46 BAROKAH',
#  '[2010] SGHC 131 ASTRO BIN JAKARIA',
#  '[2010] SGHC 212 GALING ANAK KUJAT',
#  '[2010] SGHC 82 AFR',
#  '[2012] SGHC 238 WANG ZHIJIAN',
#  '[2013] SGHC 251 KHO JABING',
#  '[2014] SGHC 23 WANG WENFENG',
#  '[2015] SGHC 292 SUTHERSON, SUJAY SOLOMON',
#  '[2017] SGHC 29 RAMZAN RIZWAN',
#  '[2017] SGHC 29 RASHEED MUHAMMAD',
#  '[2017] SGHC 307 P MAGESWARAN',
#  '[2018] SGHC 135 BPK'}

# %%
appeal_cases
# Out:
# {'[2010] SGCA 37 ONG PANG SIEW',
#  '[2012] SGCA 44 PATHIP SELVAN S/O SUGUMARAN',
#  '[2014] SGCA 58 WANG ZHIJIAN',
#  '[2015] SGCA 1 KHO JABING',
#  '[2016] SGCA 21 JABING KHO',
#  '[2016] SGCA 62 ROSMAN BIN ABDULLAH',
#  '[2017] SGCA 69 BDB',
#  '[2017] SGCA 7 MICHEAL ANAK GARING',
#  '[2017] SGCA 9 ISKANDAR BIN RAHMAT',
#  '[2018] SGCA 30 CHIA KEE CHEN',
#  '[2019] SGCA 22 P MAGESWARAN',
#  '[2019] SGCA 44 CHAN LIE SIAN'}

# %%
path = input('enter csv path to save trials metadata:\n')
trials_df[['unique_ref', 'Court', 'accused']].to_csv(path)
# Out:
# enter csv path to save trials metadata:
#  data/murder_trials_some_metadata.csv
